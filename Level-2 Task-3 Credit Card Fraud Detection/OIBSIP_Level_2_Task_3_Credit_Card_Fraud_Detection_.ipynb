# %% [markdown]
# #1.importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #2.Mount the google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #3.Importing the dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/OIBSIP Data Analytics/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# **As you can see there is no null values in this dataset**

# %% [markdown]
# #Describing the Dataset

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %% [markdown]
# #Visualization of the data

# %% [markdown]
# **Bar graph**

# %%
# Visualizations
plt.figure(figsize=(8,6))
sns.countplot(x='Class', data=df, palette='rocket')
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-13-d79ba8e21ac1>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Class', data=df, palette='rocket')

# %% [markdown]
# **A Correlation Heatmap**

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), cmap='coolwarm', annot=False)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# **Create a Box plot for Transaction Amount by class**

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Class', y='Amount', data=df, palette='coolwarm')
plt.title('Transaction Amount by Class')
plt.show()
# Out:
# <ipython-input-14-eb6f1a1e02ca>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Class', y='Amount', data=df, palette='coolwarm')

# %% [markdown]
# **Create a Distribution plot for Transaction Amounts**

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['Amount'], bins=50, kde=True, color='blue')
plt.title('Distribution of Transaction Amounts')
plt.xlabel('Amount')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Checking the value counts of the class column**

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# 0---Normal Transaction
#
# 1---Fraud Transaction

# %% [markdown]
# **We Understand that this dataset is Unbalanced**

# %% [markdown]
# #**Importing Machine Learning Libraries**

# %% [markdown]
# #`Logistic Regression`

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDOneClassSVM
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %% [markdown]
# **Statistical Measures of the Dataset**

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# **Compare the values for both transactions**

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# **Building a simple distribution for legit transactions and fraud Transactions**

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenate the two Dataframes

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 198079  132321.0  1.995968 -0.384783 -3.104994 -0.495380  2.697771  3.174543
# 42272    41024.0 -1.814466  1.277714  0.648854  1.503461 -0.526339 -0.419169
# 242128  151354.0  1.753184 -0.392859 -1.720756  0.599803 -0.173589 -1.282850
# 283342  171532.0 -1.914173  1.691579 -0.793050  1.036711  1.075035 -0.291248
# 282304  170799.0 -0.486100  0.909451  0.367840  0.075382 -0.011912 -0.613677
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 198079 -0.082563  0.652770  0.204682  ... -0.008575 -0.013277  0.076535
# 42272  -0.260248  0.957871 -0.212029  ... -0.011514  0.236176  0.266205
# 242128  0.284179 -0.305452  1.068326  ... -0.166492 -0.543541  0.070641
# 283342  1.012861  0.438448 -1.389570  ... -0.013654  0.141468 -0.824867
# 282304  0.523833  0.204217 -0.206366  ...  0.315192  0.963259 -0.097944
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      99438.906504  0.044203  0.112971 -0.036744 -0.004360  0.019922
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.017167  0.025225  0.043152  0.037319  ...  0.037641  0.028977
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.016073  0.024660 -0.029404 -0.041023 -0.047226  0.031209  0.003949
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       83.057073
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# **Splitting the dataset into feature targets**

# %%
X = new_dataset.drop(columns ='Class' , axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 198079  132321.0  1.995968 -0.384783 -3.104994 -0.495380  2.697771  3.174543
# 42272    41024.0 -1.814466  1.277714  0.648854  1.503461 -0.526339 -0.419169
# 242128  151354.0  1.753184 -0.392859 -1.720756  0.599803 -0.173589 -1.282850
# 283342  171532.0 -1.914173  1.691579 -0.793050  1.036711  1.075035 -0.291248
# 282304  170799.0 -0.486100  0.909451  0.367840  0.075382 -0.011912 -0.613677
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 198079    0
# 42272     0
# 242128    0
# 283342    0
# 282304    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# **Split  the data into training data and testing data**

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Create a Logistic Regression Model

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# **Create a Confustion Matrix for Predicted and Actual Values of the data**

# %%
# Confusion Matrix Visualization
cm = confusion_matrix(Y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='coolwarm')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# **Create a ROC Curve for False Positive Rate and True Positive Rate**

# %%
# ROC Curve
y_prob = model.predict_proba(X_test)[:,1]
fpr, tpr, _ = roc_curve(Y_test, y_prob)
roc_auc = auc(fpr, tpr)

# %% [markdown]
# Graph

# %%
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# **Accuracy Score**

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training Data : ', training_data_accuracy)
# Out:
# Accuracy on Training Data :  0.9529860228716646

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Testing Data : ', test_data_accuracy)
# Out:
# Accuracy on Testing Data :  0.9086294416243654

# %% [markdown]
# #`Decision Tree`

# %%
# Decision Tree Model
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, Y_train)
y_pred_dt = dt_model.predict(X_test)

# %% [markdown]
# **Create a Confusion matrix for Decision Tree**

# %%
# Confusion Matrix for Decision Tree
cm_dt = confusion_matrix(Y_test, y_pred_dt)
sns.heatmap(cm_dt, annot=True, fmt='d', cmap='coolwarm')
plt.title('Decision Tree Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# **Creating a Tree Structure**

# %%
# Decision Tree Visualization
plt.figure(figsize=(15,10))
tree.plot_tree(dt_model, filled=True, feature_names=df.columns[:-1], class_names=['Non-Fraud', 'Fraud'])
plt.title('Decision Tree Structure')
plt.show()

# %% [markdown]
# **Accuracy Score**

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training Data : ', training_data_accuracy)
# Out:
# Accuracy on Training Data :  0.9529860228716646

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Testing Data : ', test_data_accuracy)
# Out:
# Accuracy on Testing Data :  0.9086294416243654

# %% [markdown]
# #`Support Vector Machine `

# %%
from sklearn.svm import SVC

# %%
# Support Vector Machine (SVM) Model
svm_model = SVC(kernel='linear', probability=True)
svm_model.fit(X_train, Y_train)
y_pred_svm = svm_model.predict(X_test)

# %% [markdown]
# **Create a Confusion Matrix for Support Vector Machine**

# %%
cm_svm = confusion_matrix(Y_test, y_pred_svm)
sns.heatmap(cm_svm, annot=True, fmt='d', cmap='coolwarm')
plt.title('SVM Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# ROC Curve for SVM
y_prob_svm = svm_model.predict_proba(X_test)[:,1]
fpr_svm, tpr_svm, _ = roc_curve(Y_test, y_prob_svm)
roc_auc_svm = auc(fpr_svm, tpr_svm)

# %%
plt.figure(figsize=(8,6))
plt.plot(fpr_svm, tpr_svm, color='red', lw=2, label=f'SVM ROC Curve (area = {roc_auc_svm:.2f})')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('SVM Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **Create a Scatter Plot for V1 and V2 classes**

# %%
# Scatter Plot
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['V1'], y=df['V2'], hue=df['Class'], palette='rocket', alpha=0.5)
plt.title('Scatter Plot of V1 vs V2 by Class')
plt.xlabel('V1')
plt.ylabel('V2')
plt.show()

# %% [markdown]
# **Performance Metrices**

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, accuracy_score, precision_score, recall_score, f1_score

# %%
# Logistic Regression Model
log_model = LogisticRegression()
log_model.fit(X_train, Y_train)
y_pred = log_model.predict(X_test)

# %%
# Performance Metrics for Logistic Regression
print("\nLogistic Regression Performance Metrics:")
print(f'Accuracy: {accuracy_score(Y_test, y_pred):.4f}')
print(f'Precision: {precision_score(Y_test, y_pred):.4f}')
print(f'Recall: {recall_score(Y_test, y_pred):.4f}')
print(f'F1 Score: {f1_score(Y_test, y_pred):.4f}')
print("Classification Report:\n", classification_report(Y_test, y_pred))
# Out:
# Logistic Regression Performance Metrics:
# Accuracy: 0.9086
# Precision: 0.9545
# Recall: 0.8571
# F1 Score: 0.9032
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91        99
#            1       0.95      0.86      0.90        98
#
#     accuracy                           0.91       197
#    macro avg       0.91      0.91      0.91       197
# weighted avg       0.91      0.91      0.91       197

# %%
# Decision Tree Model
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, Y_train)
y_pred_dt = dt_model.predict(X_test)

# %%
# Performance Metrics for Decision Tree
print("\nDecision Tree Performance Metrics:")
print(f'Accuracy: {accuracy_score(Y_test, y_pred_dt):.4f}')
print(f'Precision: {precision_score(Y_test, y_pred_dt):.4f}')
print(f'Recall: {recall_score(Y_test, y_pred_dt):.4f}')
print(f'F1 Score: {f1_score(Y_test, y_pred_dt):.4f}')
print("Classification Report:\n", classification_report(Y_test, y_pred_dt))
# Out:
# Decision Tree Performance Metrics:
# Accuracy: 0.8985
# Precision: 0.9062
# Recall: 0.8878
# F1 Score: 0.8969
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90        99
#            1       0.91      0.89      0.90        98
#
#     accuracy                           0.90       197
#    macro avg       0.90      0.90      0.90       197
# weighted avg       0.90      0.90      0.90       197

# %%
# Support Vector Machine (SVM) Model
svm_model = SVC(kernel='linear', probability=True)
svm_model.fit(X_train, Y_train)
y_pred_svm = svm_model.predict(X_test)

# %%
# Performance Metrics for SVM
print("\nSVM Performance Metrics:")
print(f'Accuracy: {accuracy_score(Y_test, y_pred_svm):.4f}')
print(f'Precision: {precision_score(Y_test, y_pred_svm):.4f}')
print(f'Recall: {recall_score(Y_test, y_pred_svm):.4f}')
print(f'F1 Score: {f1_score(Y_test, y_pred_svm):.4f}')
print("Classification Report:\n", classification_report(Y_test, y_pred_svm))
# Out:
# SVM Performance Metrics:
# Accuracy: 0.9137
# Precision: 0.9551
# Recall: 0.8673
# F1 Score: 0.9091
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92        99
#            1       0.96      0.87      0.91        98
#
#     accuracy                           0.91       197
#    macro avg       0.92      0.91      0.91       197
# weighted avg       0.92      0.91      0.91       197
